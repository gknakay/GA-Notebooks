# %% [markdown]
# bunun çalışması için Selenium 3.141.0 kurdum, 4 küsür kurunca çalışmıyor.

# %%
import selenium
from selenium.webdriver.common.keys import Keys
from selenium import webdriver

import requests
import time
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np
import xlrd
import os
from tqdm import tqdm

import openpyxl
from openpyxl import Workbook, load_workbook
from openpyxl.utils import get_column_letter

# %%
os.chdir('Financials_202209')

# %%
all_stocks = [stock.split('.', 1)[0] for stock in os.listdir()]

# %%
#os.chdir('C:/Users/Gökhan Akay/Desktop/BeautifulSoup/Selenium Stocks_202209')
os.chdir('C:\\Users\\Gökhan Akay\Desktop\Masaüstü\GA-Notebooks\Stocks To DB\Selenium Stocks_202209')
existing_stocks = [stock.split('.', 1)[0] for stock in os.listdir()]

# %%
remaining_stocks = sorted(list(set(all_stocks).difference(set(existing_stocks))))

# %%
len(remaining_stocks)
# Out:
# 57

# %%
def get_data():
    soup = BeautifulSoup(html_text, 'lxml')
    table = soup.find('tbody', id = 'tbodyMTablo')
    trs = table.find_all('tr')

    #quarter_list = []
    #for i in range(0,4):
    #    quarter_list.append(soup.find_all('th', class_ = 'form-group')[0].find_all('option')[i].text)
    
    quarter_list = []
    for i in range(4):
        quarter_list.append(soup.find_all('span', id = 'select2-ddlMaliTabloDonem'+str(i+1)+'-container')[0].text)
    
    #print('get_data içindeki q_list', quarter_list)

    val_list = []
    for i in range(1,len(trs)):
        val_list.append(trs[i].find_all('td'))


    col_list = []
    for i in range(0,len(val_list)):
        col_list.append(val_list[i][0].text)

    col_list[0]
    col_list.remove('Gelir Tablosu')
    try:
        col_list.remove('Dipnot')
    except:
        pass


    try:
        col_list.remove('Nakit Akım Tablosu')
    except:
        pass

    q1 = []    
    for i in range(0,len(val_list)):
        try:
            q1.append(val_list[i][1].text)
        except:
            i = i+1

    q1[0]

    q2 = []    
    for i in range(0,len(val_list)):
        try:
            q2.append(val_list[i][2].text)
        except:
            i = i+1

    q2[0]


    q3 = []    
    for i in range(0,len(val_list)):
        try:
            q3.append(val_list[i][3].text)
        except:
            i = i+1

    q3[0]

    q4= []    
    for i in range(0,len(val_list)):
        try:
            q4.append(val_list[i][4].text)
        except:
            i = i+1   

    q4[0]

    q1 = [w.replace('.', '') for w in q1]
    q1 = list(map(float, q1))

    q2 = [w.replace('.', '') for w in q2]
    q2 = list(map(float, q2))

    q3 = [w.replace('.', '') for w in q3]
    q3 = list(map(float, q3))

    q4 = [w.replace('.', '') for w in q4]
    q4 = list(map(float, q4))

    col_list.insert(0,'')
    q1.insert(0,'')
    q2.insert(0,'')
    q3.insert(0,'')
    q4.insert(0,'')

    col_list.insert(72,'')
    q1.insert(72,'')
    q2.insert(72,'')
    q3.insert(72,'')
    q4.insert(72,'')

    col_list.insert(115,'')
    q1.insert(115,'')
    q2.insert(115,'')
    q3.insert(115,'')
    q4.insert(115,'')


    df = pd.DataFrame(index = col_list)
    df['q1'] = q1
    df['q2'] = q2
    df['q3'] = q3
    df['q4'] = q4

    df.columns = quarter_list

    # gelir tablosu ve dipnot'tan sonra gelen kısmı eliyoruz. 
    #df = df.iloc[0:124,:]
    return df, quarter_list

# %%
def update_periods(driver, period_list):
    driver.find_element_by_id('select2-ddlMaliTabloDonem1-container').click()
    time.sleep(1)
    #print(period_list[0])
    driver.find_elements_by_xpath("//*[contains(@id, '" + period_list[0]+ "')]")[0].click()

    driver.find_element_by_id('select2-ddlMaliTabloDonem2-container').click()
    time.sleep(1)
    #print(period_list[1])
    driver.find_elements_by_xpath("//*[contains(@id, '" + period_list[1]+ "')]")[0].click()

    driver.find_element_by_id('select2-ddlMaliTabloDonem3-container').click()
    time.sleep(1)
    #print(period_list[2])
    driver.find_elements_by_xpath("//*[contains(@id, '" + period_list[2]+ "')]")[0].click()

    driver.find_element_by_id('select2-ddlMaliTabloDonem4-container').click()
    time.sleep(1)
    #print(period_list[3])
    driver.find_elements_by_xpath("//*[contains(@id, '" + period_list[3]+ "')]")[0].click()

# %%
for i in tqdm(range(0, len(remaining_stocks))):
    stock = remaining_stocks[i]

    PATH = 'C:\Program Files (x86)\chromedriver.exe'
    driver = webdriver.Chrome(PATH)

    driver.get("https://www.isyatirim.com.tr/tr-tr/analiz/hisse/Sayfalar/sirket-karti.aspx?hisse="+ stock)  
    print(driver.title)
    time.sleep(3)
    
    driver.find_elements_by_class_name("cookie-policy-close")[0].click()
    time.sleep(1)

    
    driver.find_elements_by_id("page-4")[0].click()
    time.sleep(1)

    
    driver.find_element_by_id('select2-ddlMaliTabloDonem1-container').click()
    time.sleep(1)

    html_text = driver.page_source
    soup = BeautifulSoup(html_text, 'lxml')
    table = soup.find('tbody', id = 'tbodyMTablo')
    trs = table.find_all('tr')

    uls = soup.find_all('ul', id = 'select2-ddlMaliTabloDonem1-results')

    period_list = []
    for ul in uls:
        for li in ul.findAll('li'):
            period_list.append(li.text)

    period_list = [period for period in period_list if period >= '2021/0'] 
    print(period_list)

    driver.find_element_by_id('select2-ddlMaliTabloDonem1-container').click()
    time.sleep(1)
    df_list = []

    while len(period_list) >= 4:
        html_text = driver.page_source
        df1,q_list = get_data()    

        df_list.append(df1)

        period_list = [p for p in period_list if p not in q_list]

        if len(period_list) == 0:
            break

        if len(period_list) >= 8:
            update_periods(driver, period_list)
            #continue

        if len(period_list) % 4 == 0:
            update_periods(driver, period_list)        
        else:
            addition = len(period_list)%4
            for i in range(4-addition):
                period_list.append(period_list[-1])


        time.sleep(2)
        print(len(period_list))
        
    print('length of df_list:', len(df_list))
    len_list = list(map(len,df_list))
    len_list
    
    short_dfs = list(filter(lambda x: x <150, len_list))
    short_dfs
    
    if len(short_dfs) > 0:
        df_to_fix = df_list[len_list.index(short_dfs[0])]
        print('df_to_fix shape:', df_to_fix.shape)
        df_to_fix.head()

        df_to_fix_backup = df_to_fix.copy()
        df_to_fix = df_to_fix_backup.copy()
        df_to_fix2= df_to_fix.iloc[np.r_[0:72,73:142],:]
        df_to_fix = df_to_fix2.iloc[np.r_[0:114,115:141],:]

        list1 = list(df_to_fix.iloc[:,0])
        list1.insert(7,0)
        list1.insert(17,0)
        list1.insert(23,0)
        list1.insert(36,0)
        list1.insert(39,0)
        list1.insert(50,0)
        list1.insert(53,0)
        list1.insert(72,0)
        list1.insert(95,0)
        list1.insert(115,0)

        list2 = list(df_to_fix.iloc[:,1])
        list2.insert(7,0)
        list2.insert(17,0)
        list2.insert(23,0)
        list2.insert(36,0)
        list2.insert(39,0)
        list2.insert(50,0)
        list2.insert(53,0)
        list2.insert(72,0)
        list2.insert(95,0)
        list2.insert(115,0)

        list3 = list(df_to_fix.iloc[:,2])
        list3.insert(7,0)
        list3.insert(17,0)
        list3.insert(23,0)
        list3.insert(36,0)
        list3.insert(39,0)
        list3.insert(50,0)
        list3.insert(53,0)
        list3.insert(72,0)
        list3.insert(95,0)
        list3.insert(115,0)

        list4 = list(df_to_fix.iloc[:,3])
        list4.insert(7,0)
        list4.insert(17,0)
        list4.insert(23,0)
        list4.insert(36,0)
        list4.insert(39,0)
        list4.insert(50,0)
        list4.insert(53,0)
        list4.insert(72,0)
        list4.insert(95,0)
        list4.insert(115,0)

        df_fixed = pd.DataFrame(list(zip(list1,list2,list3,list4)))
        df_fixed.index = df_list[0].index
        df_fixed.columns = df_to_fix.columns

        df = pd.concat([df_list[0],df_list[1],df_list[2],df_list[3],df_list[4], df_fixed], axis = 1)

    else:    
        df = pd.concat([df_list[0],df_list[1]], axis = 1)
        i = 2
        while i < len(df_list):
            df = pd.concat([df,df_list[i]], axis = 1)
            i = i+1
            
    df.index = df.index.str.strip()

    cols_to_drop = len(set(df.columns)) - len(df.columns)
    print('cols_to_drop:', cols_to_drop)
    if cols_to_drop >0:
        df = df.iloc[:,:cols_to_drop]
    df = df.iloc[0:124,:-3]

    #os.chdir('C:\\Users\\Gökhan Akay\\Desktop\\BeautifulSoup\\Selenium Stocks')
    os.chdir('C:\\Users\\Gökhan Akay\Desktop\Masaüstü\GA-Notebooks\Stocks To DB\Selenium Stocks_202209')

    df.to_excel(stock+'.xlsx')
# Out:
# AEFES - Anadolu Efes Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# AKSA - Aksa Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# AKSEN - Aksa Enerji Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ALARK - Alarko Holding Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ALKA - Alkim Kağıt Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ALKIM - Alkim Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ARCLK - Arçelik Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ARDYZ - ARD Grup Bilişim Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ASELS - Aselsan Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# AYGAZ - Aygaz Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# BIMAS - Bim Birleşik Mağazalar A.Ş Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# BRISA - Brisa Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# CCOLA - Coca-Cola İçecek A.Ş Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# CEMTS - Çemtas Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# CIMSA - Çimsa Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# DEVA - Deva Holding Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# DOAS - Doğuş Otomotiv Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ECILC - Eczacıbaşı İlaç Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# EGEEN - Ege Endüstri Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ENJSA - Enerjisa Enerji Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ENKAI - Enka İnşaat Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ERBOS - Erbosan Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# EREGL - Ereğli Demir Çelik Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# FROTO - Ford Otosan Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# GEDZA - Gediz Ambalaj Sanayi Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# GOODY - Goodyear Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# HEKTS - Hektaş Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# JANTS - Jantsa Jant Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# KCHOL - Koç Holding Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# KORDS - Kordsa Teknik Tekstil Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# KOZAL - Koza Altın Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# KRDMD - Kardemir (D) Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# LOGO - Logo Yazılım Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# MGROS - Migros Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ORGE - ORGE Enerji Elektrik Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# OTKAR - Otokar Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# OYAKC - Oyak Çimento Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# PETKM - Petkim Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# PGSUS - Pegasus Hava Taşımacılığı Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# SAHOL - Sabancı Holding Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# SARKY - Sarkuysan Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# SASA - Sasa Polyester Sanayi A.Ş. Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# SISE - Şişecam Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# SOKM - Şok Marketler Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# TCELL - Turkcell Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# THYAO - Türk Hava Yolları Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# TKFEN - Tekfen Holding Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# TMSN - Tümosan Motor ve Traktör Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# TOASO - Tofaş Fabrika Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# TTKOM - Türk Telekom Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# TTRAK - Türk Traktör Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# TUPRS - Tüpraş Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ULKER - Ülker Bisküvi Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# ULUSE - Ulusoy Elektrik Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# VESBE - Vestel Beyaz Esya Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# VESTL - Vestel Elektronik Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
# YATAS - Yataş Yatak Hisse Senedi | İş Yatırım
# ['2022/9', '2022/6', '2022/3', '2021/12', '2021/9', '2021/6', '2021/3']
# 4
# 4
# length of df_list: 3
# cols_to_drop: -5
