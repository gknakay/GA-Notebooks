# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily, Hourly

# Set time period
start = datetime(2022, 11, 10)
end = datetime(2022, 11, 15)

# Create Point for Berlin
#location = Point(41.01,28.94, 70)
location = Point(52.5,13.4, 70)

# Get daily data for 2018
data = Daily(location, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg'])
plt.show()

# %%
data.head()
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# time
# 2022-11-01  12.3   8.9  15.9   0.1   0.0  186.0  11.6  25.9  1016.2  134.0
# 2022-11-02   9.3   6.4  13.4   0.0   0.0  227.0  15.1  42.6  1019.6  367.0
# 2022-11-03   8.0   4.2  12.4   0.0   0.0  160.0  14.6  31.5  1015.4  274.0
# 2022-11-04   8.9   7.8  10.2   2.8   0.0  242.0  10.7  27.8  1005.9    0.0
# 2022-11-05   8.0   4.7  10.6   0.0   0.0  266.0  12.1  27.8  1015.4  407.0

# %%
data.head()
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2021-11-01  14.4  13.5  15.9  10.6   NaN   27.0   9.6   NaN  1015.1   NaN
# 2021-11-02  15.0  13.5  16.9   6.3   NaN  166.0   6.7   NaN  1012.0   NaN
# 2021-11-03  17.1  14.9  20.9   1.0   NaN  235.0   7.0   NaN  1016.3   NaN
# 2021-11-04  17.2  13.9  22.1   0.0   NaN  215.0   6.0   NaN  1020.9   NaN
# 2021-11-05  15.1  11.9  18.9   0.0   NaN  215.0   5.4   NaN  1021.1   NaN

# %%
data = Hourly(location, start, end)
data = data.fetch()
data.tail(50)
# Out:
# ...
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt    pres  \
# time
# 2021-12-28 23:00:00  11.9   8.9  82.0   0.0   NaN   50.0   9.4   NaN  1012.0
# 2021-12-29 00:00:00  10.7   9.3  91.0   0.0   NaN  360.0   7.6   NaN  1012.3
# 2021-12-29 01:00:00  10.9  10.0  94.0   0.0   NaN  350.0  11.2   NaN  1011.0
# 2021-12-29 02:00:00   9.9   9.0  94.0   0.0   NaN   10.0   7.6   NaN  1011.0
# 2021-12-29 03:00:00  10.0   8.8  92.0   0.0   NaN  340.0  13.0   NaN  1011.8
# 2021-12-29 04:00:00   9.9   9.0  94.0   0.0   NaN   10.0   7.6   NaN  1011.0
# 2021-12-29 05:00:00  11.9   8.0  77.0   0.0   NaN  100.0   9.4   NaN  1011.0
# 2021-12-29 06:00:00  11.9   6.6  70.0   0.0   NaN  120.0  13.0   NaN  1011.1
# 2021-12-29 07:00:00  11.9   6.0  67.0   0.0   NaN  110.0  13.0   NaN  1011.0
# 2021-12-29 08:00:00  11.9   6.0  67.0   0.0   NaN  120.0  11.2   NaN  1011.0
# 2021-12-29 09:00:00  12.5   6.1  65.0   0.0   NaN  120.0  14.8   NaN  1011.1
# ...

# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily, Hourly

# Set time period
# start = datetime(2022, 1, 1)
# end = datetime(2022, 3, 26)

# Create Point for İstanbul
location = Point(41.01,28.94, 70)

# Get daily data for 2018
data = Daily(location, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg'])
#data.plot(y = ['temp'])
plt.show()
